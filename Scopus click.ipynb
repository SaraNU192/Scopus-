# %%
import openpyxl
import re
import os
import pandas as pd
def extract_links_from_excel(file_path):

    workbook = openpyxl.load_workbook(file_path)
    sheet = workbook.active
    links = []
    for row in sheet.iter_rows(min_row=1, max_row=sheet.max_row, min_col=3, max_col=3):  
        for cell in row:
            if cell.value and 'http' in str(cell.value):
                links.append(cell.value)
    workbook.close()

    return links
author_ids =[]
file_path = 'D:\Scopus\Profiles links.xlsx'
links = extract_links_from_excel(file_path)
for link in links:
    print(link)
# Out:
# https://www.scopus.com/authid/detail.uri?origin=resultslist&authorId=8503356600&zone=
# https://www.scopus.com/authid/detail.uri?origin=resultslist&authorId=7103379659&zone=
# https://www.scopus.com/authid/detail.uri?authorId=58639488200
# https://www.scopus.com/authid/detail.uri?origin=resultslist&authorId=57192702484&zone=
# https://www.scopus.com/authid/detail.uri?origin=resultslist&authorId=57203044258&zone=
# https://www.scopus.com/authid/detail.uri?origin=resultslist&authorId=26025748900&zone=
# https://www.scopus.com/authid/detail.uri?authorId=57008318500
# https://www.scopus.com/authid/detail.uri?origin=resultslist&authorId=35728774600&zone=
# https://www.scopus.com/authid/detail.uri?origin=resultslist&authorId=57214486419&zone=
# https://www.scopus.com/authid/detail.uri?origin=resultslist&authorId=57919411700&zone=
# https://www.scopus.com/authid/detail.uri?origin=resultslist&authorId=57420390500&zone=
# ...

# %%
def extract_author_ids_from_excel(file_path, sheet_name):
    author_ids = []
    workbook = openpyxl.load_workbook(file_path)
    sheet = workbook[sheet_name]
    for row in sheet.iter_rows(values_only=True):
        cell_value = row[2]  
        match = re.search(r'authorId=(\d+)', str(cell_value))
        if match:
            author_ids.append(match.group(1))
    return author_ids
author_ids = extract_author_ids_from_excel("D:\Scopus\Profiles links.xlsx", "Sheet1")

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time 
from selenium.webdriver.support.ui import Select
import pandas as pd
file_path = "D:\Scopus\Profiles links.xlsx"
df = pd.read_excel(file_path)
header = df.columns[1]
second_column_names = df.iloc[:, 1].tolist()
second_column_names.insert(0, header)
i = 0
for link in links:
    driver = webdriver.Firefox()
    driver.get(link)
    signin_bttn = driver.find_element(By.XPATH, '//*[@id="signin_link_move"]')
    signin_bttn.click();
    time.sleep(6)
    email_ = driver.find_element(By.XPATH, '//*[@id="bdd-email"]')
    email_.send_keys("SSweilam@nu.edu.eg")
    time.sleep(6)
    accpet =  driver.find_element(By.XPATH, '//*[@id="onetrust-accept-btn-handler"]')
    accpet.click();
    time.sleep(3)
    email_ = driver.find_element(By.XPATH, '//*[@id="bdd-email"]')
    email_.send_keys("SSweilam@nu.edu.eg")
    time.sleep(2)
    cont_bttn = driver.find_element(By.XPATH, '//*[@id="bdd-elsPrimaryBtn"]')
    cont_bttn.click();
    time.sleep(5)
    pass_ = driver.find_element(By.XPATH, '//*[@id="bdd-password"]')
    pass_.send_keys("Sasonono2000")
    time.sleep(5)
    final_bttn = driver.find_element(By.XPATH, '//*[@id="bdd-elsPrimaryBtn"]')
    final_bttn.click();
    time.sleep(5)
    total_height = driver.execute_script("return document.body.scrollHeight")
    middle_position= 370
    driver.execute_script(f"window.scrollTo(0, {middle_position});")
    time.sleep(14)
    try: 
        ddelement= driver.find_element(By.XPATH, '/html/body/div/div/div[1]/div[2]/div/div[3]/div[10]/div[5]/form/micro-ui/scopus-author-profile-page-control-microui/div[1]/div[3]/div/div/div[3]/div[1]/div/div/div[2]/div[2]/ul/li[1]/div/span/button').click()
        ddelement_ = driver.find_element(By.XPATH, '/html/body/div/div/div[1]/div[2]/div/div[3]/div[10]/div[5]/form/micro-ui/scopus-author-profile-page-control-microui/div[1]/div[3]/div/div/div[3]/div[1]/div/div/div[2]/div[2]/ul/li[1]/div/span/div/div[1]/button[1]/span').click()
        ddelement_cli = driver.find_element(By.XPATH, '/html/body/div/div/div[1]/div[2]/div/div[3]/div[10]/div[5]/form/micro-ui/scopus-author-profile-page-control-microui/div[1]/div[3]/div/div/div[3]/div[1]/div/div/div[2]/div[2]/ul/li[1]/div[2]/div/div/section/div[1]/div/div/div/div/div[2]/span/label/input').click()
        ddelement_cli_2 = driver.find_element(By.XPATH, '/html/body/div/div/div[1]/div[2]/div/div[3]/div[10]/div[5]/form/micro-ui/scopus-author-profile-page-control-microui/div[1]/div[3]/div/div/div[3]/div[1]/div/div/div[2]/div[2]/ul/li[1]/div[2]/div/div/section/div[1]/div/div/div/div/div[3]/span/label/input').click()
        ddelement_cli_3 = driver.find_element(By.XPATH, '/html/body/div/div/div[1]/div[2]/div/div[3]/div[10]/div[5]/form/micro-ui/scopus-author-profile-page-control-microui/div[1]/div[3]/div/div/div[3]/div[1]/div/div/div[2]/div[2]/ul/li[1]/div[2]/div/div/section/div[1]/div/div/div/div/div[4]/span/label/input').click()
        ddelement_cli_4 = driver.find_element(By.XPATH, '/html/body/div/div/div[1]/div[2]/div/div[3]/div[10]/div[5]/form/micro-ui/scopus-author-profile-page-control-microui/div[1]/div[3]/div/div/div[3]/div[1]/div/div/div[2]/div[2]/ul/li[1]/div[2]/div/div/section/div[1]/div/div/div/div/div[5]/span/label/input').click()
        ddelement_export = driver.find_element(By.XPATH, '/html/body/div/div/div[1]/div[2]/div/div[3]/div[10]/div[5]/form/micro-ui/scopus-author-profile-page-control-microui/div[1]/div[3]/div/div/div[3]/div[1]/div/div/div[2]/div[2]/ul/li[1]/div[2]/div/div/section/div[2]/div/div/span[2]/div/div/button').click()
    # except Exception as e:
    #     print(e)
    # time.sleep(10) 
    # downloads_path = os.path.join(os.path.expanduser('~'), 'Downloads')
    # files = [os.path.join(downloads_path, file) for file in os.listdir(downloads_path)]
    # csv_files = [file for file in files if file.endswith('.csv')]
    # sorted_csv_files = sorted(csv_files, key=os.path.getmtime, reverse=True)

    # if not sorted_csv_files:
    #     print("No CSV files found in the Downloads directory.")
    #     exit()

    # author_id = link.split("authorId=")[1].split("&")[0]
    # last_csv_path = sorted_csv_files[0]
    # new_name = author_id + "_" + second_column_names[i] + ".csv"
    # new_csv_path = os.path.join(downloads_path, new_name)

 
    # time.sleep(10)

    # try:
    #     os.rename(last_csv_path, new_csv_path)
    #     print(f"File renamed from {last_csv_path} to {new_csv_path}")
    # except Exception as e:
    #     print(f"Error renaming file: {e}")

    # i += 1
# Out:
# Error renaming file: [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\Research Coordinator\\Downloads\\scopus(59).csv' -> 'C:\\Users\\Research Coordinator\\Downloads\\8503356600_Mohamed Mamdouh Hamed Awny.csv'
# File renamed from C:\Users\Research Coordinator\Downloads\scopus(59).csv to C:\Users\Research Coordinator\Downloads\7103379659_Ahmed Gomaa Ahmed Radwan .csv
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 69
#      66 new_csv_path = os.path.join(downloads_path, new_name)
#      68 # Wait for 10 seconds to ensure the file is fully downloaded
# ---> 69 time.sleep(10)
#      71 try:
#      72     os.rename(last_csv_path, new_csv_path)
#
# KeyboardInterrupt:
